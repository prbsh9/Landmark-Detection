# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %% [markdown]
# # Let's test keras(.h5 file)

# %%
classes = ['boudha','golden_temple','nyatapole','pashupati_temple','patan','rara_lake','tilicho_lake']

# %%
model_path = '/gdrive/My Drive/main_data/mobi_best.h5'


from keras.models import load_model
model = load_model(model_path)

# %%
# Compile 
from keras.optimizers import Adam

model.compile(optimizer=Adam(lr=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# import os
# os.chdir('/gdrive/My Drive/main_data/test') # Change dir to testing folder

# %%
from keras.preprocessing import image
import numpy as np
import os

n = 0
for dir in os.listdir('/gdrive/My Drive/main_data/test'): # Freaking loops to get the images on the 7 folders and test them out
  for img in os.listdir(dir):
    n = n+1
    test_image = image.load_img(dir+'/'+ img, target_size = (224, 224))




    test_image = image.img_to_array(test_image)
    test_image = np.expand_dims(test_image, axis = 0)

    #predict the result
    result = model.predict(test_image)
    result = result[0]
    result = np.array(result).tolist()
    result =  classes[result.index(max(result))]
    if result != dir:
      print(dir, result, img)
    else:
      pass
    
# test_image = image.load_img('/gdrive/My Drive/main_data/test/golden_temple/IMG_20190620_123226.jpg', target_size = (224, 224)) 
print(n)
# Out:
# boudha pashupati_temple boudha265.jpg
# boudha patan boudha306.jpg
# tilicho_lake rara_lake 00000031.gif
# 68

# %%
from keras.preprocessing import image
import numpy as np
import os

test_image = image.load_img('/gdrive/My Drive/main_data/test/boudha/boudha265.jpg', target_size = (224, 224)) 


test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)

#predict the result
result = model.predict(test_image)
result
# Out:
# array([[0.2488471 , 0.1143999 , 0.0519746 , 0.25064245, 0.09080475,
#         0.08505456, 0.15827669]], dtype=float32)

# %%
result = [ 9.9157941e-01, 2.2307334e-03, 5.5244652e-04,5.7619112e-04, 1.1510049e-03, 2.5950728e-03]

result.index(max(result))
# Out:
# 0

# %%
for dir in os.listdir('/gdrive/My Drive/main_data/test'):
  print(dir)
# Out:
# golden_temple
# patan
# boudha
# nyatapole
# rara_lake
# tilicho_lake
# pashupati_temple
# panch_pokhari

# %%
values = [0, 1, 2, 1]
values.index(max(values))
# Out:
# 2

# %%
print(classes[0] + '= ' + str(result[0][0]))
print(second_class + '= ' + str(result[0][1]))
# Out:
# Boudha = 0.98299986
# Nyatpole = 0.017000165

# %% [markdown]
# ##  Let's test with .tflite file to know whether our model performance is depriciated or not

# %%
import numpy as np
import tensorflow as tf

# Load TFLite model and allocate tensors.
interpreter = tf.lite.Interpreter(model_path="/gdrive/My Drive/Places/yes.tflite")
# interpreter = tf.lite.Interpreter(model_path="/gdrive/My Drive/Places/model.tflite")
# interpreter = tf.lite.Interpreter(model_path="/gdrive/My Drive/Places/final.tflite")
# interpreter = tf.lite.Interpreter(model_path="/gdrive/My Drive/Places/f.tflite")


interpreter.allocate_tensors()

# Get input and output tensors.
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Test model on random input data.
input_shape = input_details[0]['shape']

#Let's test it with the own data

import cv2
im = cv2.imread("/gdrive/My Drive/Places/ssss.jpg")
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
im = np.float32(ima1)
im = np.reshape(final, (1, 224, 224, 3))


input_data = np.array(im, dtype=np.float32)
# input_data = np.array(im, dtype=np.uint8)

interpreter.set_tensor(input_details[0]['index'], input_data)

interpreter.invoke()
output_data = interpreter.get_tensor(output_details[-1]['index'])
print(output_data)
# print(input_data)
# Out:
# [[0.9739621  0.02603791]]
